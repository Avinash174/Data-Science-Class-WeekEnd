# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
image=plt.imread('/Users/avinashmagar/Documents/Code/class/personal_practice/a.jpg')
image
# Out:
# array([[[ 10,  12,  33],
#         [  8,  10,  31],
#         [  7,   9,  30],
#         ...,
#         [114,  26,  50],
#         [117,  27,  52],
#         [118,  28,  53]],
#
#        [[ 10,  12,  33],
#         [  8,  10,  31],
#         [  7,   9,  30],
#         ...,
#         [114,  26,  50],
#         [117,  27,  52],
#         [118,  28,  53]],
#
#        [[ 10,  12,  33],
#         [  8,  10,  31],
#         [  7,   9,  30],
#         ...,
#         [115,  25,  50],
#         [117,  27,  52],
#         [119,  29,  54]],
#
#        ...,
#
#        [[  8,  23,  52],
#         [  6,  21,  50],
#         [  5,  20,  49],
#         ...,
#         [146,  26,  64],
#         [147,  27,  65],
#         [148,  28,  66]],
#
#        [[  8,  23,  52],
#         [  6,  21,  50],
#         [  5,  20,  49],
#         ...,
#         [146,  26,  64],
#         [147,  27,  65],
#         [148,  28,  66]],
#
#        [[  8,  23,  52],
#         [  6,  21,  50],
#         [  5,  20,  49],
#         ...,
#         [145,  25,  63],
#         [147,  27,  65],
#         [148,  28,  66]]], dtype=uint8)

# %%
grayscale_image = np.dot(image[:, :, :3], [0.2989, 0.5870, 0.1140]) 
grayscale_image
# Out:
# array([[13.795 , 11.7952, 10.7953, ..., 55.0366, 56.7483, 57.7482],
#        [13.795 , 11.7952, 10.7953, ..., 55.0366, 56.7483, 57.7482],
#        [13.795 , 11.7952, 10.7953, ..., 54.7485, 56.7483, 58.7481],
#        ...,
#        [21.8202, 19.8204, 18.8205, ..., 66.1974, 67.1973, 68.1972],
#        [21.8202, 19.8204, 18.8205, ..., 66.1974, 67.1973, 68.1972],
#        [21.8202, 19.8204, 18.8205, ..., 65.1975, 67.1973, 68.1972]])

# %%
flipped_image = np.flipud(image)
flipped_image
# Out:
# array([[[  8,  23,  52],
#         [  6,  21,  50],
#         [  5,  20,  49],
#         ...,
#         [145,  25,  63],
#         [147,  27,  65],
#         [148,  28,  66]],
#
#        [[  8,  23,  52],
#         [  6,  21,  50],
#         [  5,  20,  49],
#         ...,
#         [146,  26,  64],
#         [147,  27,  65],
#         [148,  28,  66]],
#
#        [[  8,  23,  52],
#         [  6,  21,  50],
#         [  5,  20,  49],
#         ...,
#         [146,  26,  64],
#         [147,  27,  65],
#         [148,  28,  66]],
#
#        ...,
#
#        [[ 10,  12,  33],
#         [  8,  10,  31],
#         [  7,   9,  30],
#         ...,
#         [115,  25,  50],
#         [117,  27,  52],
#         [119,  29,  54]],
#
#        [[ 10,  12,  33],
#         [  8,  10,  31],
#         [  7,   9,  30],
#         ...,
#         [114,  26,  50],
#         [117,  27,  52],
#         [118,  28,  53]],
#
#        [[ 10,  12,  33],
#         [  8,  10,  31],
#         [  7,   9,  30],
#         ...,
#         [114,  26,  50],
#         [117,  27,  52],
#         [118,  28,  53]]], dtype=uint8)

# %%
cropped_image = image[100:300, 200:400]

# %%
plt.imshow(grayscale_image, cmap='gray')

# %%
plt.axis('off')
plt.show()

# %%
plt.show()
