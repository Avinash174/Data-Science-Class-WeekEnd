# %%
# pandas Library

import pandas as pd
l=[10,12,89,87,50]
se=pd.Series(l)
print(se)
# Out:
# 0    10
# 1    12
# 2    89
# 3    87
# 4    50
# dtype: int64

# %%
import pandas as pd

l = [10, 12, 89, 87, 50]
ind = ['a', 'b', 'c', 'd', 'e']
se = pd.Series(l, index=ind)
print(se)
# Out:
# a    10
# b    12
# c    89
# d    87
# e    50
# dtype: int64

# %%
import numpy as np
a=np.arange(10,100,10)
pd.Series(a)
se
# Out:
# a    10
# b    12
# c    89
# d    87
# e    50
# dtype: int64

# %%
d={'age':[29,20,10,76,64,54]}
se2=pd.Series(d)
se2
# Out:
# age    [29, 20, 10, 76, 64, 54]
# dtype: object

# %%
se
# Out:
# a    10
# b    12
# c    89
# d    87
# e    50
# dtype: int64

# %%
se['c']
# Out:
# 89

# %%
d
# Out:
# {'age': [29, 20, 10, 76, 64, 54]}

# %%
# filtering a series

se[se>=30]
# Out:
# c    89
# d    87
# e    50
# dtype: int64

# %%
se[se<=30]
# Out:
# a    10
# b    12
# dtype: int64

# %%
a = pd.Series([1, 2, 3, 4, 5, 6])  
b = pd.Series([6, 7, 8, 9, 11, 2]) 
result = a * b  
print(result)
# Out:
# 0     6
# 1    14
# 2    24
# 3    36
# 4    55
# 5    12
# dtype: int64

# %%
a = pd.Series([1, 2, 3, 4, 5, 6]) 
a+2
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# 5    8
# dtype: int64

# %%
a = pd.Series([1, 2, 3, 4, 5, 6]) 
a-2
# Out:
# 0   -1
# 1    0
# 2    1
# 3    2
# 4    3
# 5    4
# dtype: int64

# %%
a = pd.Series([1, 2, 3, 4, 5, 6]) 
a/3
# Out:
# 0    0.333333
# 1    0.666667
# 2    1.000000
# 3    1.333333
# 4    1.666667
# 5    2.000000
# dtype: float64

# %%
a = pd.Series([1, 2, 3, 4, 5, 6]) 
a%2==0
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
# DataFrame

l=[10,20,30,40]
pd.DataFrame(l)
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40

# %%
data={"name":['avinash','peter','lisa'],
      "age":[24,25,40],
      "salary":[2000,1000,4000]
      }
df=pd.DataFrame(data)
df
# Out:
#       name  age  salary
# 0  avinash   24    2000
# 1    peter   25    1000
# 2     lisa   40    4000

# %%
df=pd.read_csv("/Users/avinashmagar/Documents/Code/class/python/Evenning/ipl_player_auction.csv")
df
# Out:
#       PLAYER NAME  AGE       COUNTRY PLAYING ROLE  T-RUNS  T-WKTS  ODI-RUNS-S  \
# 0         Abdulla    2  South Africa   Allrounder       0       0           0
# 1    Abdur Razzak    2    Bangladesh       Bowler     266      18         657
# 2         Agarkar    2         India       Bowler     669      58        1269
# 3          Ashwin    1         India       Bowler     308      31         241
# 4       Badrinath    2         India      Batsman     109       0          79
# ..            ...  ...           ...          ...     ...     ...         ...
# 125         Yadav    2         India      Batsman      68       0           0
# 126   Younis Khan    2      Pakistan      Batsman    6488       7        6814
# 127  Yuvraj Singh    2         India      Batsman    1785       9        8051
# 128   Zaheer Khan    2         India       Bowler    1194     288         790
# 129         Zoysa    2     Sri Lanka       Bowler     328      64         343
#
# ...

# %%
df.head() # first 5 value from top
df.head(15)
# Out:
#      PLAYER NAME  AGE       COUNTRY PLAYING ROLE  T-RUNS  T-WKTS  ODI-RUNS-S  \
# 0        Abdulla    2  South Africa   Allrounder       0       0           0
# 1   Abdur Razzak    2    Bangladesh       Bowler     266      18         657
# 2        Agarkar    2         India       Bowler     669      58        1269
# 3         Ashwin    1         India       Bowler     308      31         241
# 4      Badrinath    2         India      Batsman     109       0          79
# 5         Bailey    2     Australia      Batsman       0       0         172
# 6         Balaji    2         India       Bowler     126      27         120
# 7      Bollinger    2     Australia       Bowler     108      50          50
# 8          Botha    2  South Africa   Allrounder     133      17         609
# 9        Boucher    2  South Africa    W. Keeper    5545       1        4686
# 10         Bravo    2   West Indies   Allrounder    2219      86        2004
# ...

# %%
df.tail(10) # bottom 5 value
# Out:
#       PLAYER NAME  AGE      COUNTRY PLAYING ROLE  T-RUNS  T-WKTS  ODI-RUNS-S  \
# 120       Vettori    2  New Zealand   Allrounder    4521     359        2105
# 121   Vinay Kumar    2        India       Bowler      43       1          43
# 122         Warne    3    Australia       Bowler    3201     708        1018
# 123        Warner    1    Australia      Batsman     562       2         876
# 124         White    2    Australia      Batsman     219       5        2037
# 125         Yadav    2        India      Batsman      68       0           0
# 126   Younis Khan    2     Pakistan      Batsman    6488       7        6814
# 127  Yuvraj Singh    2        India      Batsman    1785       9        8051
# 128   Zaheer Khan    2        India       Bowler    1194     288         790
# 129         Zoysa    2    Sri Lanka       Bowler     328      64         343
#
#      ODI-SR-B  ODI-WKTS  ODI-SR-BL  ...   HS    AVE    SR-B  SIXERS  RUNS-C  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PLAYER NAME    130 non-null    object
#  1   AGE            130 non-null    int64
#  2   COUNTRY        130 non-null    object
#  3   PLAYING ROLE   130 non-null    object
#  4   T-RUNS         130 non-null    int64
#  5   T-WKTS         130 non-null    int64
#  6   ODI-RUNS-S     130 non-null    int64
#  7   ODI-SR-B       130 non-null    float64
#  8   ODI-WKTS       130 non-null    int64
#  9   ODI-SR-BL      130 non-null    float64
#  10  CAPTAINCY EXP  130 non-null    int64
#  11  RUNS-S         130 non-null    int64
#  12  HS             130 non-null    int64
#  13  AVE            130 non-null    float64
#  14  SR-B           130 non-null    float64
#  15  SIXERS         130 non-null    int64
#  16  RUNS-C         130 non-null    int64
# ...
